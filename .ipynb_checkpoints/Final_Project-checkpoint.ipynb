# %% [markdown]
# <a href="https://colab.research.google.com/github/Montasir00/Ml_final_project/blob/monti/Final_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Final Project**
#
# Team members:
# 1. Pham Gia Khiem - 551026 (Vietnam)
# 2. Mohammed Hassan – 541140 (Bangladesh)
# 3. Fazlur Rahman - 541927 (Bangladesh)

# %% [markdown]
# ### Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ### Understanding the dataset

# %% [markdown]
# ### Loading the dataset

# %%
df = pd.read_csv('data/final_project_dataset_complete.csv', index_col = False)
df
# Out:
#       feature_1  feature_2  feature_3  feature_4  feature_5  feature_6  \
# 0      0.496714   1.146509  -0.648521   0.833005   0.784920  -2.209437
# 1     -0.138264  -0.061846        NaN   0.403768   0.704674  -2.498565
# 2      0.647689   1.395115  -0.764126   1.708266  -0.250029   1.956259
# 3      1.523030   2.657560  -2.461653   2.649051   0.882201   3.445638
# 4     -0.234153  -0.499391   0.576097  -0.441656   0.610601   0.211425
# ...         ...        ...        ...        ...        ...        ...
# 8995   0.101630   0.400250        NaN  -0.019412  -0.063150   0.077627
# 8996   1.167218   2.177774  -1.716067   1.994835   0.350043  -0.544915
# 8997   1.588447   3.333945  -2.615488   3.476880  -0.933276   2.027658
# 8998  -0.684987  -1.599835   1.063341  -1.252109  -0.724001   2.228943
# 8999   0.801182   1.808647  -1.383917   1.841776   0.702840  -0.339918
#
#       feature_7  feature_8     category_1 category_2  target
# 0     -1.300105  -2.242241  Above Average   Region C       1
# 1     -1.339227  -1.942298  Below Average   Region A       0
# 2      1.190238   1.503559           High   Region C       1
# 3      2.120913   3.409035           High   Region B       1
# 4      0.935759  -0.401463  Below Average   Region C       0
# ...         ...        ...            ...        ...     ...
# 8995   0.540975  -0.169030  Above Average   Region A       0
# 8996   0.089050  -0.944220           High   Region C       1
# 8997   0.239583   1.951491           High   Region C       1
# 8998   0.989794   1.936476            Low   Region B       0
# 8999  -0.027882  -0.462744           High   Region C       1
#
# [9000 rows x 11 columns]

# %%
# Describe each feature
for column in df.columns:
    print(f"Feature: {column}")
    print(df[column].value_counts() if df[column].dtype == 'object' else df[column].describe())
    print("\n")
# Out:
# Feature: feature_1
# count    9000.000000
# mean        0.000427
# std         1.241318
# min       -18.665400
# 25%        -0.680062
# 50%        -0.003938
# 75%         0.680513
# max        21.934496
# Name: feature_1, dtype: float64
#
#
# Feature: feature_2
# count    9000.000000
# mean        0.003349
# std         2.508324
# min       -37.852816
# 25%        -1.382610
# 50%        -0.016698
# 75%         1.380228
# max        47.603454
# Name: feature_2, dtype: float64
#
#
# Feature: feature_3
# count    8600.000000
# mean        0.003235
# std         1.542901
# min        -6.676680
# 25%        -1.022085
# 50%         0.005196
# 75%         1.038571
# max         6.203055
# Name: feature_3, dtype: float64
#
#
# Feature: feature_4
# count    9000.000000
# mean       -0.008481
# std         2.061784
# min        -8.190124
# 25%        -1.399928
# 50%        -0.019541
# 75%         1.394151
# max         8.189001
# Name: feature_4, dtype: float64
#
#
# Feature: feature_5
# count    9000.000000
# mean       -0.002177
# std         0.577415
# min        -0.999791
# 25%        -0.502614
# 50%         0.001695
# 75%         0.497004
# max         0.999914
# Name: feature_5, dtype: float64
#
#
# Feature: feature_6
# count    8500.000000
# mean       -0.006447
# std         1.981615
# min        -8.590782
# 25%        -1.329040
# 50%        -0.003137
# 75%         1.324897
# max         6.803751
# Name: feature_6, dtype: float64
#
#
# Feature: feature_7
# count    9000.000000
# mean        0.000592
# std         1.075064
# min        -4.422265
# 25%        -0.700078
# 50%        -0.000097
# 75%         0.731942
# max         3.857219
# Name: feature_7, dtype: float64
#
#
# Feature: feature_8
# count    9000.000000
# mean        0.003348
# std         2.043643
# min        -9.474989
# 25%        -1.356620
# 50%        -0.007584
# 75%         1.402024
# max         7.572578
# Name: feature_8, dtype: float64
#
#
# Feature: category_1
# category_1
# Low              2802
# High             2763
# Above Average    1727
# Below Average    1708
# Name: count, dtype: int64
#
#
# Feature: category_2
# category_2
# Region B    3618
# Region A    3551
# Region C    1831
# Name: count, dtype: int64
#
#
# Feature: target
# count    9000.000000
# mean        0.475444
# std         0.499424
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         1.000000
# Name: target, dtype: float64

# %%
df.head()
# Out:
#    feature_1  feature_2  feature_3  feature_4  feature_5  feature_6  \
# 0   0.496714   1.146509  -0.648521   0.833005   0.784920  -2.209437
# 1  -0.138264  -0.061846        NaN   0.403768   0.704674  -2.498565
# 2   0.647689   1.395115  -0.764126   1.708266  -0.250029   1.956259
# 3   1.523030   2.657560  -2.461653   2.649051   0.882201   3.445638
# 4  -0.234153  -0.499391   0.576097  -0.441656   0.610601   0.211425
#
#    feature_7  feature_8     category_1 category_2  target
# 0  -1.300105  -2.242241  Above Average   Region C       1
# 1  -1.339227  -1.942298  Below Average   Region A       0
# 2   1.190238   1.503559           High   Region C       1
# 3   2.120913   3.409035           High   Region B       1
# 4   0.935759  -0.401463  Below Average   Region C       0

# %%
df.describe()
# Out:
#          feature_1    feature_2    feature_3    feature_4    feature_5  \
# count  9000.000000  9000.000000  8600.000000  9000.000000  9000.000000
# mean      0.000427     0.003349     0.003235    -0.008481    -0.002177
# std       1.241318     2.508324     1.542901     2.061784     0.577415
# min     -18.665400   -37.852816    -6.676680    -8.190124    -0.999791
# 25%      -0.680062    -1.382610    -1.022085    -1.399928    -0.502614
# 50%      -0.003938    -0.016698     0.005196    -0.019541     0.001695
# 75%       0.680513     1.380228     1.038571     1.394151     0.497004
# max      21.934496    47.603454     6.203055     8.189001     0.999914
#
#          feature_6    feature_7    feature_8       target
# count  8500.000000  9000.000000  9000.000000  9000.000000
# mean     -0.006447     0.000592     0.003348     0.475444
# std       1.981615     1.075064     2.043643     0.499424
# min      -8.590782    -4.422265    -9.474989     0.000000
# 25%      -1.329040    -0.700078    -1.356620     0.000000
# 50%      -0.003137    -0.000097    -0.007584     0.000000
# 75%       1.324897     0.731942     1.402024     1.000000
# max       6.803751     3.857219     7.572578     1.000000

# %%
# Checking for missing values
df.isnull().sum()
# Out:
# feature_1       0
# feature_2       0
# feature_3     400
# feature_4       0
# feature_5       0
# feature_6     500
# feature_7       0
# feature_8       0
# category_1      0
# category_2      0
# target          0
# dtype: int64

# %%
# Checking the number of unique values in each column to identify categorical features.
df.nunique()
# Out:
# feature_1     9000
# feature_2     9000
# feature_3     8600
# feature_4     9000
# feature_5     9000
# feature_6     8500
# feature_7     9000
# feature_8     9000
# category_1       4
# category_2       3
# target           2
# dtype: int64

# %%
# Calculates the number of duplicate rows in the DataFrame df.
df.duplicated().sum()
# Out:
# 0

# %%
# Visualize the distribution of numerical features in the DataFrame
df.hist(bins = 30, figsize=(15,10), edgecolor = 'black')
plt.suptitle("Distribution of numerical features", fontsize = 15)
plt.show()

# %%
# Visualize the distribution of numerical features in the DataFrame using boxplot
plt.figure(figsize =(20, 10))
sns.boxplot(data = df, palette="husl")
# Add gridlines to the plot
plt.grid(True)

# Add labels and title
plt.xlabel("Features")
plt.ylabel("Values")
plt.title('Box plot of numerical features')
# Out:
# Text(0.5, 1.0, 'Box plot of numerical features')

# %%
# Select only columns with numerical data types (float64 and int64) 
numeric_df = df.select_dtypes(include=['float64', 'int64'])

# %%
numeric_df.head()
# Out:
#    feature_1  feature_2  feature_3  feature_4  feature_5  feature_6  \
# 0   0.496714   1.146509  -0.648521   0.833005   0.784920  -2.209437
# 1  -0.138264  -0.061846        NaN   0.403768   0.704674  -2.498565
# 2   0.647689   1.395115  -0.764126   1.708266  -0.250029   1.956259
# 3   1.523030   2.657560  -2.461653   2.649051   0.882201   3.445638
# 4  -0.234153  -0.499391   0.576097  -0.441656   0.610601   0.211425
#
#    feature_7  feature_8  target
# 0  -1.300105  -2.242241       1
# 1  -1.339227  -1.942298       0
# 2   1.190238   1.503559       1
# 3   2.120913   3.409035       1
# 4   0.935759  -0.401463       0

# %%
#  Calculating the correlation matrix for the DataFrame
corr_matrix_cleaned = numeric_df.corr()

# %%
corr_matrix_cleaned
# Out:
#            feature_1  feature_2  feature_3  feature_4  feature_5  feature_6  \
# feature_1   1.000000   0.995360  -0.831705   0.831922  -0.015305  -0.010813
# feature_2   0.995360   1.000000  -0.823242   0.832002  -0.014715  -0.011519
# feature_3  -0.831705  -0.823242   1.000000  -0.957222   0.011309   0.003989
# feature_4   0.831922   0.832002  -0.957222   1.000000  -0.003613  -0.000213
# feature_5  -0.015305  -0.014715   0.011309  -0.003613   1.000000  -0.009365
# feature_6  -0.010813  -0.011519   0.003989  -0.000213  -0.009365   1.000000
# feature_7  -0.010843  -0.011393   0.006042  -0.001369   0.252371   0.921569
# feature_8  -0.004581  -0.005394   0.001846   0.001202  -0.012717   0.969998
# target      0.605940   0.606016  -0.704351   0.694885  -0.007873   0.001457
#
#            feature_7  feature_8    target
# feature_1  -0.010843  -0.004581  0.605940
# feature_2  -0.011393  -0.005394  0.606016
# feature_3   0.006042   0.001846 -0.704351
# feature_4  -0.001369   0.001202  0.694885
# feature_5   0.252371  -0.012717 -0.007873
# feature_6   0.921569   0.969998  0.001457
# feature_7   1.000000   0.894220 -0.002000
# feature_8   0.894220   1.000000  0.004658
# target     -0.002000   0.004658  1.000000

# %%
# Visualizing the correlation matrix heatmap
fig = plt.figure(figsize=(10,8))
sns.heatmap(corr_matrix_cleaned, annot=True, cmap ='coolwarm',fmt='0.2f')
plt.title('Correlation Heatmap Of Features')
plt.show()

# %%
# Create a figure with specified size
fig, ax = plt.subplots(figsize=(10, 8))
# Visualizing the correlation between features and target using scatterplot
sns.scatterplot(data=corr_matrix_cleaned, palette='coolwarm', alpha=0.8, s=50, ax=ax)

ax.set_xlabel('Features')
ax.set_ylabel('Correlation')

plt.legend(bbox_to_anchor=(1.01, 1), loc='upper left', borderaxespad=0) 

# Show the plot
plt.show()

# %% [markdown]
# ### Data Preprocessing

# %%
# Checking for missing values
df.isna().sum()
# Out:
# feature_1       0
# feature_2       0
# feature_3     400
# feature_4       0
# feature_5       0
# feature_6     500
# feature_7       0
# feature_8       0
# category_1      0
# category_2      0
# target          0
# dtype: int64

# %%
# assigning missing values to a variable
missing_values = df.isna().sum()

# Display columns with missing values
missing_values = missing_values[missing_values > 0]
print(missing_values)
# Out:
# feature_3    400
# feature_6    500
# dtype: int64

# %% [markdown]
# ### Handling missing values of Numerical Features

# %%
# Using SimpleImputer class to fill in missing values(NaN) with median of each column
imputer = SimpleImputer(missing_values=np.nan, strategy='median')
df['feature_3'] = imputer.fit_transform(df[['feature_3']])
df['feature_6'] = imputer.fit_transform(df[['feature_6']])

# %%
# Checking to see if any messing values left or not 
df['feature_3'].isna().sum()
df['feature_6'].isna().sum()
# Out:
# 0

# %%
numerical_features = df.select_dtypes(include=['float64', 'int64'])

plt.figure(figsize=(20,10))
plt.title('Box plot of numerical features before removing outliers')
sns.boxplot(data=numerical_features)
plt.show()

# %%
def iqr_outliers(dataset, feature_name, multiplier= 1.5):
    # Calculate IQR
    Q1 = dataset[feature_name].quantile(0.25)
    Q3 = dataset[feature_name].quantile(0.75)
    IQR = Q3 - Q1
    
    # Calculate limits
    lower_limit = Q1 - multiplier * IQR
    upper_limit = Q3 + multiplier * IQR
    
    # Identify outliers
    outliers = dataset[(dataset[feature_name] < lower_limit) | (dataset[feature_name] > upper_limit)]
    
    return outliers, {'lower_limit': lower_limit, 'upper_limit': upper_limit}

outliers_detected = {}

for feature in numerical_features.columns:  
    outliers, limits = iqr_outliers(numerical_features, feature)
    outliers_detected[feature] = {
        'count': len(outliers),
        'indices': outliers.index.tolist(),
        'limits': limits
    }
    
    print(f'Feature: {feature}')
    print(f'Number of outliers: {len(outliers)}')
    print(f'Lower limit: {limits["lower_limit"]}, Upper limit: {limits["upper_limit"]}')
    print(f'Outlier indices: {outliers.index.tolist()}')
    print('-' * 50)
# Out:
# Feature: feature_1
# Number of outliers: 113
# Lower limit: -2.7209235765630777, Upper limit: 2.7213742002161805
# Outlier indices: [209, 262, 277, 469, 478, 496, 598, 774, 1061, 1101, 1400, 1445, 1539, 1591, 1615, 1785, 1957, 1971, 2024, 2035, 2093, 2218, 2228, 2305, 2336, 2442, 2458, 2506, 2521, 2884, 2895, 2947, 3017, 3152, 3227, 3241, 3245, 3336, 3454, 3510, 3569, 3716, 3872, 3982, 3986, 4026, 4029, 4033, 4047, 4091, 4198, 4207, 4265, 4359, 4531, 4617, 4635, 4639, 4725, 4779, 4784, 4870, 4997, 5157, 5224, 5316, 5416, 5488, 5587, 5642, 5649, 5673, 5773, 5796, 5846, 5907, 5935, 5998, 6350, 6408, 6628, 6693, 6738, 6747, 6891, 7060, 7140, 7178, 7223, 7290, 7305, 7330, 7441, 7498, 7611, 7624, 7677, 7839, 7851, 7858, 7872, 7874, 8024, 8067, 8165, 8180, 8200, 8248, 8283, 8354, 8630, 8714, 8726]
# --------------------------------------------------
# Feature: feature_2
# Number of outliers: 106
# Lower limit: -5.526868048459379, Upper limit: 5.524485931793154
# Outlier indices: [209, 262, 277, 469, 478, 496, 598, 774, 1061, 1101, 1400, 1445, 1591, 1615, 1785, 1957, 1971, 2024, 2093, 2218, 2228, 2305, 2336, 2442, 2458, 2506, 2895, 2947, 3017, 3152, 3227, 3241, 3245, 3336, 3454, 3510, 3569, 3716, 3872, 3982, 3986, 4006, 4026, 4029, 4047, 4091, 4198, 4207, 4265, 4359, 4531, 4617, 4635, 4639, 4725, 4779, 4870, 4997, 5157, 5224, 5316, 5416, 5488, 5587, 5642, 5649, 5773, 5796, 5846, 5907, 5935, 5998, 6058, 6408, 6541, 6628, 6693, 6738, 6747, 6891, 7060, 7140, 7178, 7223, 7290, 7305, 7330, 7441, 7611, 7624, 7677, 7839, 7851, 7858, 8024, 8067, 8165, 8180, 8200, 8248, 8283, 8311, 8354, 8630, 8714, 8726]
# --------------------------------------------------
# Feature: feature_3
# Number of outliers: 107
# Lower limit: -3.892214150332281, Upper limit: 3.8914688784594933
# Outlier indices: [209, 262, 478, 646, 654, 668, 755, 762, 880, 977, 1061, 1101, 1346, 1355, 1453, 1539, 1591, 1615, 1649, 1750, 1911, 1957, 1971, 2024, 2035, 2118, 2258, 2506, 2521, 2574, 2801, 2895, 2947, 3017, 3152, 3241, 3434, 3454, 3553, 3716, 3717, 3982, 4033, 4047, 4198, 4207, 4593, 4617, 4635, 4639, 4725, 4779, 4850, 4855, 4870, 5157, 5224, 5271, 5507, 5535, 5587, 5642, 5670, 5673, 5796, 5808, 5846, 5901, 6194, 6252, 6350, 6473, 6518, 6723, 6738, 6755, 6891, 6917, 6958, 7096, 7108, 7140, 7223, 7290, 7305, 7330, 7441, 7498, 7611, 7624, 7677, 7736, 7766, 7858, 7872, 7874, 8024, 8165, 8180, 8200, 8248, 8283, 8311, 8373, 8500, 8602, 8726]
# --------------------------------------------------
# Feature: feature_4
# Number of outliers: 71
# Lower limit: -5.5910477589733345, Upper limit: 5.5852704539022096
# Outlier indices: [113, 209, 262, 478, 646, 668, 755, 1101, 1160, 1346, 1491, 1562, 1591, 1615, 1750, 1957, 2024, 2305, 2506, 2574, 2895, 2947, 2989, 3152, 3241, 3454, 3553, 3716, 3982, 4198, 4207, 4617, 4635, 4725, 4779, 4784, 4850, 4870, 4997, 5157, 5224, 5507, 5796, 5808, 5846, 5907, 6058, 6194, 6252, 6723, 6738, 6891, 7140, 7223, 7290, 7305, 7330, 7441, 7611, 7677, 7783, 7858, 8024, 8165, 8180, 8200, 8248, 8283, 8311, 8500, 8726]
# --------------------------------------------------
# Feature: feature_5
# Number of outliers: 0
# Lower limit: -2.0020420195928015, Upper limit: 1.996432123992288
# Outlier indices: []
# --------------------------------------------------
# Feature: feature_6
# Number of outliers: 119
# Lower limit: -4.947744137293393, Upper limit: 4.955711724895908
# Outlier indices: [25, 75, 97, 162, 265, 287, 592, 720, 754, 958, 974, 1262, 1315, 1338, 1356, 1366, 1610, 1858, 1905, 1950, 1956, 2003, 2024, 2044, 2254, 2311, 2353, 2379, 2406, 2472, 2515, 2759, 2769, 2783, 3099, 3212, 3282, 3286, 3291, 3369, 3375, 3462, 3518, 3554, 3659, 3706, 3824, 3868, 3900, 3923, 4047, 4147, 4155, 4228, 4230, 4239, 4320, 4385, 4486, 4851, 4852, 4862, 5151, 5266, 5357, 5425, 5436, 5536, 5598, 5650, 5663, 5745, 5786, 5799, 6022, 6048, 6056, 6096, 6105, 6200, 6215, 6370, 6400, 6458, 6558, 6646, 6677, 6831, 6879, 6921, 6936, 6982, 7031, 7138, 7172, 7178, 7187, 7352, 7363, 7583, 7652, 7867, 7943, 7952, 8036, 8119, 8142, 8149, 8239, 8256, 8461, 8521, 8566, 8569, 8723, 8729, 8779, 8865, 8891]
# --------------------------------------------------
# Feature: feature_7
# Number of outliers: 69
# Lower limit: -2.848107565515858, Upper limit: 2.8799711793607106
# Outlier indices: [8, 75, 265, 340, 592, 754, 804, 892, 958, 1315, 1356, 1956, 2024, 2059, 2254, 2353, 2406, 2472, 2538, 2664, 2783, 3088, 3212, 3234, 3518, 3554, 3741, 3900, 3923, 4147, 4228, 4239, 4320, 4385, 4486, 4592, 5151, 5266, 5360, 5436, 5475, 5554, 5650, 5786, 5799, 5994, 6022, 6096, 6105, 6458, 6470, 6677, 6696, 6879, 7022, 7138, 7151, 7178, 7187, 7352, 7462, 7583, 7867, 7978, 8256, 8551, 8569, 8649, 8922]
# --------------------------------------------------
# Feature: feature_8
# Number of outliers: 61
# Lower limit: -5.494585664401815, Upper limit: 5.539989640848478
# Outlier indices: [75, 97, 265, 541, 592, 720, 754, 958, 992, 1315, 1356, 1446, 1912, 1956, 2254, 2406, 2624, 2769, 3234, 3240, 3398, 3462, 3518, 3842, 3900, 4047, 4155, 4162, 4239, 4468, 4592, 4862, 5151, 5436, 5536, 5650, 5786, 5994, 6006, 6105, 6215, 6274, 6370, 6677, 6831, 6879, 7138, 7178, 7352, 7363, 7583, 7652, 7867, 7943, 7952, 8036, 8149, 8256, 8569, 8723, 8891]
# --------------------------------------------------
# Feature: target
# Number of outliers: 0
# Lower limit: -1.5, Upper limit: 2.5
# Outlier indices: []
# --------------------------------------------------

# %%
df_stage1 = df.copy()
# Loop through the outliers_detected dictionary and replace the outliers with median values

for feature, values in outliers_detected.items():
    # Get outlier indices
    outlier_indices = values['indices']  
    
    # Calculate the median value for the feature
    median_value = df_stage1[feature].median()
    
    # Replace the outlier values with the median value
    df_stage1.loc[outlier_indices, feature] = median_value
    
    # Print out some information for verification
    print(f"Feature: {feature}")
    print(f"Replaced outliers in indices: {outlier_indices}")
    print('-' * 50)
# Out:
# Feature: feature_1
# Replaced outliers in indices: [209, 262, 277, 469, 478, 496, 598, 774, 1061, 1101, 1400, 1445, 1539, 1591, 1615, 1785, 1957, 1971, 2024, 2035, 2093, 2218, 2228, 2305, 2336, 2442, 2458, 2506, 2521, 2884, 2895, 2947, 3017, 3152, 3227, 3241, 3245, 3336, 3454, 3510, 3569, 3716, 3872, 3982, 3986, 4026, 4029, 4033, 4047, 4091, 4198, 4207, 4265, 4359, 4531, 4617, 4635, 4639, 4725, 4779, 4784, 4870, 4997, 5157, 5224, 5316, 5416, 5488, 5587, 5642, 5649, 5673, 5773, 5796, 5846, 5907, 5935, 5998, 6350, 6408, 6628, 6693, 6738, 6747, 6891, 7060, 7140, 7178, 7223, 7290, 7305, 7330, 7441, 7498, 7611, 7624, 7677, 7839, 7851, 7858, 7872, 7874, 8024, 8067, 8165, 8180, 8200, 8248, 8283, 8354, 8630, 8714, 8726]
# --------------------------------------------------
# Feature: feature_2
# Replaced outliers in indices: [209, 262, 277, 469, 478, 496, 598, 774, 1061, 1101, 1400, 1445, 1591, 1615, 1785, 1957, 1971, 2024, 2093, 2218, 2228, 2305, 2336, 2442, 2458, 2506, 2895, 2947, 3017, 3152, 3227, 3241, 3245, 3336, 3454, 3510, 3569, 3716, 3872, 3982, 3986, 4006, 4026, 4029, 4047, 4091, 4198, 4207, 4265, 4359, 4531, 4617, 4635, 4639, 4725, 4779, 4870, 4997, 5157, 5224, 5316, 5416, 5488, 5587, 5642, 5649, 5773, 5796, 5846, 5907, 5935, 5998, 6058, 6408, 6541, 6628, 6693, 6738, 6747, 6891, 7060, 7140, 7178, 7223, 7290, 7305, 7330, 7441, 7611, 7624, 7677, 7839, 7851, 7858, 8024, 8067, 8165, 8180, 8200, 8248, 8283, 8311, 8354, 8630, 8714, 8726]
# --------------------------------------------------
# Feature: feature_3
# Replaced outliers in indices: [209, 262, 478, 646, 654, 668, 755, 762, 880, 977, 1061, 1101, 1346, 1355, 1453, 1539, 1591, 1615, 1649, 1750, 1911, 1957, 1971, 2024, 2035, 2118, 2258, 2506, 2521, 2574, 2801, 2895, 2947, 3017, 3152, 3241, 3434, 3454, 3553, 3716, 3717, 3982, 4033, 4047, 4198, 4207, 4593, 4617, 4635, 4639, 4725, 4779, 4850, 4855, 4870, 5157, 5224, 5271, 5507, 5535, 5587, 5642, 5670, 5673, 5796, 5808, 5846, 5901, 6194, 6252, 6350, 6473, 6518, 6723, 6738, 6755, 6891, 6917, 6958, 7096, 7108, 7140, 7223, 7290, 7305, 7330, 7441, 7498, 7611, 7624, 7677, 7736, 7766, 7858, 7872, 7874, 8024, 8165, 8180, 8200, 8248, 8283, 8311, 8373, 8500, 8602, 8726]
# --------------------------------------------------
# Feature: feature_4
# Replaced outliers in indices: [113, 209, 262, 478, 646, 668, 755, 1101, 1160, 1346, 1491, 1562, 1591, 1615, 1750, 1957, 2024, 2305, 2506, 2574, 2895, 2947, 2989, 3152, 3241, 3454, 3553, 3716, 3982, 4198, 4207, 4617, 4635, 4725, 4779, 4784, 4850, 4870, 4997, 5157, 5224, 5507, 5796, 5808, 5846, 5907, 6058, 6194, 6252, 6723, 6738, 6891, 7140, 7223, 7290, 7305, 7330, 7441, 7611, 7677, 7783, 7858, 8024, 8165, 8180, 8200, 8248, 8283, 8311, 8500, 8726]
# --------------------------------------------------
# Feature: feature_5
# Replaced outliers in indices: []
# --------------------------------------------------
# Feature: feature_6
# Replaced outliers in indices: [25, 75, 97, 162, 265, 287, 592, 720, 754, 958, 974, 1262, 1315, 1338, 1356, 1366, 1610, 1858, 1905, 1950, 1956, 2003, 2024, 2044, 2254, 2311, 2353, 2379, 2406, 2472, 2515, 2759, 2769, 2783, 3099, 3212, 3282, 3286, 3291, 3369, 3375, 3462, 3518, 3554, 3659, 3706, 3824, 3868, 3900, 3923, 4047, 4147, 4155, 4228, 4230, 4239, 4320, 4385, 4486, 4851, 4852, 4862, 5151, 5266, 5357, 5425, 5436, 5536, 5598, 5650, 5663, 5745, 5786, 5799, 6022, 6048, 6056, 6096, 6105, 6200, 6215, 6370, 6400, 6458, 6558, 6646, 6677, 6831, 6879, 6921, 6936, 6982, 7031, 7138, 7172, 7178, 7187, 7352, 7363, 7583, 7652, 7867, 7943, 7952, 8036, 8119, 8142, 8149, 8239, 8256, 8461, 8521, 8566, 8569, 8723, 8729, 8779, 8865, 8891]
# --------------------------------------------------
# Feature: feature_7
# Replaced outliers in indices: [8, 75, 265, 340, 592, 754, 804, 892, 958, 1315, 1356, 1956, 2024, 2059, 2254, 2353, 2406, 2472, 2538, 2664, 2783, 3088, 3212, 3234, 3518, 3554, 3741, 3900, 3923, 4147, 4228, 4239, 4320, 4385, 4486, 4592, 5151, 5266, 5360, 5436, 5475, 5554, 5650, 5786, 5799, 5994, 6022, 6096, 6105, 6458, 6470, 6677, 6696, 6879, 7022, 7138, 7151, 7178, 7187, 7352, 7462, 7583, 7867, 7978, 8256, 8551, 8569, 8649, 8922]
# --------------------------------------------------
# Feature: feature_8
# Replaced outliers in indices: [75, 97, 265, 541, 592, 720, 754, 958, 992, 1315, 1356, 1446, 1912, 1956, 2254, 2406, 2624, 2769, 3234, 3240, 3398, 3462, 3518, 3842, 3900, 4047, 4155, 4162, 4239, 4468, 4592, 4862, 5151, 5436, 5536, 5650, 5786, 5994, 6006, 6105, 6215, 6274, 6370, 6677, 6831, 6879, 7138, 7178, 7352, 7363, 7583, 7652, 7867, 7943, 7952, 8036, 8149, 8256, 8569, 8723, 8891]
# --------------------------------------------------
# Feature: target
# Replaced outliers in indices: []
# --------------------------------------------------

# %%
plt.figure(figsize=(20,10))
plt.title('Box plot of numerical features after handling outliers')
sns.boxplot(data=df_stage1)
plt.show()

# %%
df_stage1.describe()
# Out:
#          feature_1    feature_2    feature_3    feature_4    feature_5  \
# count  9000.000000  9000.000000  9000.000000  9000.000000  9000.000000
# mean     -0.000672     0.002354     0.005988    -0.010226    -0.002177
# std       0.971927     1.959564     1.429225     1.986669     0.577415
# min      -2.712613    -5.486925    -3.881410    -5.569645    -0.999791
# 25%      -0.657194    -1.346706    -0.939994    -1.377240    -0.502614
# 50%      -0.003938    -0.016698     0.005196    -0.019541     0.001695
# 75%       0.659561     1.343450     0.941969     1.368650     0.497004
# max       2.720169     5.516173     3.854354     5.552331     0.999914
#
#          feature_6    feature_7    feature_8       target
# count  9000.000000  9000.000000  9000.000000  9000.000000
# mean      0.004222     0.006010     0.010578     0.475444
# std       1.818435     1.038181     1.980097     0.499424
# min      -4.936580    -2.819977    -5.490152     0.000000
# 25%      -1.186692    -0.684357    -1.329677     0.000000
# 50%      -0.003137    -0.000097    -0.007584     0.000000
# 75%       1.202089     0.720851     1.386503     1.000000
# max       4.950231     2.876070     5.529430     1.000000

# %% [markdown]
# #### Lebeling the categorical features

# %%
category_columns = df_stage1[['category_1', 'category_2']]

for column in category_columns:
    unique_values = df_stage1[column].unique() 
    unique_count = df_stage1[column].nunique() 
    
    print(f"Column '{column}':")
    print(f"Unique values: {unique_values}")
    print(f"Number of unique options: {unique_count}")
    print('-' * 30)
# Out:
# Column 'category_1':
# Unique values: ['Above Average' 'Below Average' 'High' 'Low']
# Number of unique options: 4
# ------------------------------
# Column 'category_2':
# Unique values: ['Region C' 'Region A' 'Region B']
# Number of unique options: 3
# ------------------------------

# %%
# Making a copy of the dataset to avoid changing the original data
df_stage2 = df_stage1.copy()
label_encoder = LabelEncoder()
label_encoder = LabelEncoder()
df_stage2['cat_1_encoded'] = label_encoder.fit_transform(df_stage2['category_1'])
# One-Hot Encoding for category_2 (nominal)
df_one_hot = pd.get_dummies(df_stage2['category_2'])

# Combine the original dataframe with the one-hot encoded dataframe
df_stage2 = pd.concat([df_stage2, df_one_hot], axis=1)

# Drop the original category_2 column if no longer needed
df_stage2.drop(columns=['category_1', 'category_2'], inplace=True)

# Display the final dataframe
df_stage2.head()
# Out:
#    feature_1  feature_2  feature_3  feature_4  feature_5  feature_6  \
# 0   0.496714   1.146509  -0.648521   0.833005   0.784920  -2.209437
# 1  -0.138264  -0.061846   0.005196   0.403768   0.704674  -2.498565
# 2   0.647689   1.395115  -0.764126   1.708266  -0.250029   1.956259
# 3   1.523030   2.657560  -2.461653   2.649051   0.882201   3.445638
# 4  -0.234153  -0.499391   0.576097  -0.441656   0.610601   0.211425
#
#    feature_7  feature_8  target  cat_1_encoded  Region A  Region B  Region C
# 0  -1.300105  -2.242241       1              0     False     False      True
# 1  -1.339227  -1.942298       0              1      True     False     False
# 2   1.190238   1.503559       1              2     False     False      True
# 3   2.120913   3.409035       1              2     False      True     False
# 4   0.935759  -0.401463       0              1     False     False      True

# %%
print(f'Before changing column names:\n {df_stage2.columns}')

# Renaming columns
df_stage2.rename(columns={
    'Region A': 'region_A',
    'Region B': 'region_B',
    'Region C': 'region_C'
}, inplace=True)

# Verify column names
print(f'After changing column names:\n {df_stage2.columns}')
# Out:
# Before changing column names:
#  Index(['feature_1', 'feature_2', 'feature_3', 'feature_4', 'feature_5',
#        'feature_6', 'feature_7', 'feature_8', 'target', 'cat_1_encoded',
#        'Region A', 'Region B', 'Region C'],
#       dtype='object')
# After changing column names:
#  Index(['feature_1', 'feature_2', 'feature_3', 'feature_4', 'feature_5',
#        'feature_6', 'feature_7', 'feature_8', 'target', 'cat_1_encoded',
#        'region_A', 'region_B', 'region_C'],
#       dtype='object')

# %%
df_stage2.hist(bins = 30, figsize=(15,10), edgecolor = 'black')
plt.suptitle("Distribution of numerical features", fontsize = 15)
plt.show()

# %%
df_stage2.describe()
# Out:
#          feature_1    feature_2    feature_3    feature_4    feature_5  \
# count  9000.000000  9000.000000  9000.000000  9000.000000  9000.000000
# mean     -0.000672     0.002354     0.005988    -0.010226    -0.002177
# std       0.971927     1.959564     1.429225     1.986669     0.577415
# min      -2.712613    -5.486925    -3.881410    -5.569645    -0.999791
# 25%      -0.657194    -1.346706    -0.939994    -1.377240    -0.502614
# 50%      -0.003938    -0.016698     0.005196    -0.019541     0.001695
# 75%       0.659561     1.343450     0.941969     1.368650     0.497004
# max       2.720169     5.516173     3.854354     5.552331     0.999914
#
#          feature_6    feature_7    feature_8       target  cat_1_encoded
# count  9000.000000  9000.000000  9000.000000  9000.000000    9000.000000
# mean      0.004222     0.006010     0.010578     0.475444       1.737778
# std       1.818435     1.038181     1.980097     0.499424       1.095463
# min      -4.936580    -2.819977    -5.490152     0.000000       0.000000
# 25%      -1.186692    -0.684357    -1.329677     0.000000       1.000000
# 50%      -0.003137    -0.000097    -0.007584     0.000000       2.000000
# 75%       1.202089     0.720851     1.386503     1.000000       3.000000
# max       4.950231     2.876070     5.529430     1.000000       3.000000

# %%
df_stage3 = df_stage2.copy()

scaler = MinMaxScaler()

# Loop through each numerical feature and apply MinMax scaling
for feature in df_stage3:
    df_stage3[feature] = scaler.fit_transform(df_stage3[[feature]])

# Display the first few rows of the normalized dataset
print(df_stage3.head())
# Out:
#    feature_1  feature_2  feature_3  feature_4  feature_5  feature_6  \
# 0   0.590734   0.602870   0.417915   0.575676   0.892487   0.275836
# 1   0.473855   0.493050   0.502421   0.537082   0.852358   0.246593
# 2   0.618523   0.625464   0.402970   0.654372   0.374936   0.697175
# 3   0.779645   0.740199   0.183532   0.738960   0.941135   0.847818
# 4   0.456204   0.453284   0.576221   0.461068   0.805315   0.520694
#
#    feature_7  feature_8  target  cat_1_encoded  region_A  region_B  region_C
# 0   0.266829   0.294740     1.0       0.000000       0.0       0.0       1.0
# 1   0.259961   0.321959     0.0       0.333333       1.0       0.0       0.0
# 2   0.704035   0.634662     1.0       0.666667       0.0       0.0       1.0
# 3   0.867424   0.807579     1.0       0.666667       0.0       1.0       0.0
# 4   0.659358   0.461786     0.0       0.333333       0.0       0.0       1.0

# %%
plt.figure(figsize=(20,10))
plt.title('Box plot of after scaling')
sns.boxplot(data=df_stage3)
plt.show()

# %%
df_stage4 = df_stage3.copy()
# Function to engineer new features
def feature_engineering(df_stage4):
    # Create new features based on existing ones
    df_stage4['feature_9'] = df_stage4['feature_1'] / (df_stage4['feature_2'] + 1)
    df_stage4['feature_10'] = df_stage4['feature_3'] / (df_stage4['feature_4'] + 1)
    return df_stage4

# Apply feature engineering
df_stage4 = feature_engineering(df_stage4)

# Display the first few rows with new features
df_stage4.head()
# Out:
#    feature_1  feature_2  feature_3  feature_4  feature_5  feature_6  \
# 0   0.590734   0.602870   0.417915   0.575676   0.892487   0.275836
# 1   0.473855   0.493050   0.502421   0.537082   0.852358   0.246593
# 2   0.618523   0.625464   0.402970   0.654372   0.374936   0.697175
# 3   0.779645   0.740199   0.183532   0.738960   0.941135   0.847818
# 4   0.456204   0.453284   0.576221   0.461068   0.805315   0.520694
#
#    feature_7  feature_8  target  cat_1_encoded  region_A  region_B  region_C  \
# 0   0.266829   0.294740     1.0       0.000000       0.0       0.0       1.0
# 1   0.259961   0.321959     0.0       0.333333       1.0       0.0       0.0
# 2   0.704035   0.634662     1.0       0.666667       0.0       0.0       1.0
# 3   0.867424   0.807579     1.0       0.666667       0.0       1.0       0.0
# 4   0.659358   0.461786     0.0       0.333333       0.0       0.0       1.0
#
#    feature_9  feature_10
# 0   0.368548    0.265229
# 1   0.317373    0.326866
# 2   0.380521    0.243579
# 3   0.448021    0.105541
# 4   0.313913    0.394383
